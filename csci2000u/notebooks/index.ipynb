# %% [markdown]
# # CSCI 2000U: Scientific Data Analysis

# %% [markdown]
# ## Text book
#
# `PDSHB` (Python Data Science Handbook)
#
# <img width="200px" src="attachment:b921a46e-a6db-467e-a6d6-8584d534c460.png"></img>

# %% [markdown]
# # Week 1, 2
#
# ## Python Programming
#
# - IPython and Jupyter (PDSH)
#     - ~Kernel and Interactive programming in REPL~
#     - Libraries
#     - Scripts
#
# - Advanced Python Features (DSFS: Chapter 2)
#     - Python modules
#     - Python classes
#     - Generators and iterators
#     - List Comprehension
#     - Functional tools
#     - Functions
#         - Lambda
#         - Higher order
#         - args and kwargs

# %% [markdown]
# # Week 3, 4
#
# ## NumPy
#
# - NumPy arrays
#     - Basics
#     - Indexing and slicing
#     - Reshaping
#     - Concatenation and splitting
#
# - Computation with NumPy arrays
#     - Universal functions
#     - Aggregation
#     - Broadcasting
#
# - Advanced Indexing
#     - Masking and boolean logic
#     - Fancy indexing
#     - Sorting and argsort

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# # Week 5, 6
#
# ## Pandas (Chapter 3)
#
# - Basic Pandas objects
#     - Series
#     - DataFrame
#     - Index
#
# - Data Selection
#
# - Data Operations
#     - Index preservation and alignment
#     - Missing data and handling null values
#
# - Hierarchical indexes
#     - Multi-index creation
#     - Indexing and slicing
#     - Rearranging
#     - Aggregation using existing multi-index
#
# - Combining datasets
#     - Concat
#     - Append
#     - Merge
#     - Join
#
# - Aggregation and grouping
# - Pivot tables
# - String functions
# - Timeserie

# %% [markdown]
# # Week 7, 8
#
# ## Data Visualization (Chapter 4)
#
# - Plotting with Matplotlib
#     - Line
#     - Scatter
#     - Error plots
#     - Bar
#
# - More plots
#     - Density and contour
#     - Histogram
#
# - Annotations
#     - Legends
#     - Subplots
#     - Text and shape annotations
#
# - Other plotting libraries
#     - Seaborn
#     - Bokeh

# %% [markdown]
# # Week 9, 10
#
# - Regression models
#     - Linear regression
#     - Logistic regression
#
# - Advanced Scikit Learn models
